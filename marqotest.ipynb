# %%
conda install marqo
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - marqo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     marqo-0.1.16               |     pyhd8ed1ab_0          21 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          21 KB
#
# The following packages will be UPDATED:
#
#   marqo                                 0.1.15-pyhd8ed1ab_0 --> 0.1.16-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
# marqo-0.1.16         | 21 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import marqo

mq = marqo.Client(url='http://localhost:8882')

# %%
mq.index("my-index").add_documents([
    {
        "Title": "leo Messi",
        "Description": "Messi has set the world record for a goals in a single calendar year, with a grand total of 91, beating the previous all-time best set in 1972 by Germany"
    }, 
    {
        "Title": "Cristiano Ronaldo",
        "Description": "Ronaldo's highest season return was 61, which he achieved in 2014-15, and he surpassed the 50-goal mark every season for six years between 2010-11 and 2015-16, ",
    
    },
    {
      "Title": "Mo Salah",
        "Description": "Salah found the back of the net an astonishing 32 times in the 2017/18 season for the Reds."  
    },
    
    {
      "Title": "Andy Cole",
        "Description": "scored 34 goals for Newcastle in 1993/94"  
    },
    
    {
      "Title": "Alan Shearer",
        "Description": "scored 34 goals for Blackburn Rovers in 1994/95 "  
    },
    
    {
      "Title": "Harry Kane",
        "Description": "Kane's breakout season came in 2014-15 when he notched 21 EPL goals "  
    },
     
    {
      "Title": "Thierry Henry",
        "Description": "With 24 goals and 20 assists in the league, Henry set a new record for most assists in a single Premier League season "  
    },
])

results = mq.index("my-index").search(
    q="Who is the best player ever?"
)

# %%
import pprint
pprint.pprint(results)
# Out:
# {'hits': [{'Description': "Ronaldo's highest season return was 61, which he "
#                           'achieved in 2014-15, and he surpassed the 50-goal '
#                           'mark every season for six years between 2010-11 and '
#                           '2015-16, ',
#            'Title': 'Cristiano Ronaldo',
#            '_highlights': {'Title': 'Cristiano Ronaldo'},
#            '_id': 'a2c001d5-4daa-4c3a-90b1-15cfc483d40b',
#            '_score': 0.75712067},
#           {'Description': "Ronaldo's highest season return was 61, which he "
#                           'achieved in 2014-15, and he surpassed the 50-goal '
#                           'mark every season for six years between 2010-11 and '
#                           '2015-16, ',
#            'Title': 'Cristiano Ronaldo',
#            '_highlights': {'Title': 'Cristiano Ronaldo'},
#            '_id': 'c8248cd7-8012-45f8-b480-f701d0b3c179',
#            '_score': 0.75712067},
#           {'Description': "Ronaldo's highest season return was 61, which he "
#                           'achieved in 2014-15, and he surpassed the 50-goal '
#                           'mark every season for six years between 2010-11 and '
#                           '2015-16, ',
#            'Title': 'Cristiano Ronaldo',
#            '_highlights': {'Title': 'Cristiano Ronaldo'},
#            '_id': 'f7786152-2941-43c6-b686-5d8e4bcd4a72',
#            '_score': 0.75712067},
#           {'Description': 'With 24 goals and 20 assists in the league, Henry '
#                           'set a new record for most assists in a single '
#                           'Premier League season ',
#            'Title': 'Thierry Henry',
#            '_highlights': {'Title': 'Thierry Henry'},
#            '_id': '47a92fe7-9d01-4e41-9343-b8a36ad22c51',
#            '_score': 0.732561},
#           {'Description': 'With 24 goals and 20 assists in the league, Henry '
#                           'set a new record for most assists in a single '
#                           'Premier League season ',
#            'Title': 'Thierry Henry',
#            '_highlights': {'Title': 'Thierry Henry'},
#            '_id': '221b6229-076d-4e8f-8d0a-c23b4695f74d',
#            '_score': 0.732561},
#           {'Description': 'With 24 goals and 20 assists in the league, Henry '
#                           'set a new record for most assists in a single '
#                           'Premier League season ',
#            'Title': 'Thierry Henry',
#            '_highlights': {'Title': 'Thierry Henry'},
#            '_id': 'd36f7dd0-77c8-437b-a625-8e32b9c1c57e',
#            '_score': 0.732561},
#           {'Description': 'Messi has set the world record for a goals in a '
#                           'single calendar year, with a grand total of 91, '
#                           'beating the previous all-time best set in 1972 by '
#                           'Germany',
#            'Title': 'leo Messi',
#            '_highlights': {'Title': 'leo Messi'},
#            '_id': 'd46d3e79-15ee-43cd-bc6f-4a37bc4e1a11',
#            '_score': 0.7016475},
#           {'Description': 'Messi has set the world record for a goals in a '
#                           'single calendar year, with a grand total of 91, '
#                           'beating the previous all-time best set in 1972 by '
#                           'Germany',
#            'Title': 'leo Messi',
#            '_highlights': {'Title': 'leo Messi'},
#            '_id': '87016a6e-250f-4313-a866-2931611a87c7',
#            '_score': 0.7016475},
#           {'Description': 'Messi has set the world record for a goals in a '
#                           'single calendar year, with a grand total of 91, '
#                           'beating the previous all-time best set in 1972 by '
#                           'Germany',
#            'Title': 'leo Messi',
#            '_highlights': {'Title': 'leo Messi'},
#            '_id': '3df79506-a249-4a80-8149-ae6e9706f674',
#            '_score': 0.7016475},
#           {'Description': "Kane's breakout season came in 2014-15 when he "
#                           'notched 21 EPL goals ',
#            'Title': 'Harry Kane',
#            '_highlights': {'Title': 'Harry Kane'},
#            '_id': '489e6d06-9142-4eb2-969b-3d3455e8e0ad',
#            '_score': 0.69668543}],
#  'limit': 10,
#  'processingTimeMs': 103,
#  'query': 'Who is the best player ever?'}
